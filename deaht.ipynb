# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_death = pd.read_csv('life-expectancy.csv')
df_death
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1950
# 1      Afghanistan  AFG  1951
# 2      Afghanistan  AFG  1952
# 3      Afghanistan  AFG  1953
# 4      Afghanistan  AFG  1954
# ...            ...  ...   ...
# 20750     Zimbabwe  ZWE  2017
# 20751     Zimbabwe  ZWE  2018
# 20752     Zimbabwe  ZWE  2019
# 20753     Zimbabwe  ZWE  2020
# 20754     Zimbabwe  ZWE  2021
#
#        Period life expectancy at birth - Sex: all - Age: 0
# 0                                                27.7275
# 1                                                27.9634
# 2                                                28.4456
# 3                                                28.9304
# 4                                                29.2258
# ...                                                  ...
# 20750                                            60.7095
# 20751                                            61.4141
# 20752                                            61.2925
# ...

# %%
df_death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20755 entries, 0 to 20754
# Data columns (total 4 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Entity                                               20755 non-null  object
#  1   Code                                                 19061 non-null  object
#  2   Year                                                 20755 non-null  int64
#  3   Period life expectancy at birth - Sex: all - Age: 0  20755 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 648.7+ KB

# %% [markdown]
# ### Eda

# %%
df1 = df_death.copy()
df1.head()
# Out:
#         Entity Code  Year  Period life expectancy at birth - Sex: all - Age: 0
# 0  Afghanistan  AFG  1950                                            27.7275
# 1  Afghanistan  AFG  1951                                            27.9634
# 2  Afghanistan  AFG  1952                                            28.4456
# 3  Afghanistan  AFG  1953                                            28.9304
# 4  Afghanistan  AFG  1954                                            29.2258

# %%
df1['Entity'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Americas', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
# ...

# %%
#Renombrando columna
df1.rename(columns={'Period life expectancy at birth - Sex: all - Age: 0': 'Age'}, inplace= True)
df1.head()
# Out:
#         Entity Code  Year      Age
# 0  Afghanistan  AFG  1950  27.7275
# 1  Afghanistan  AFG  1951  27.9634
# 2  Afghanistan  AFG  1952  28.4456
# 3  Afghanistan  AFG  1953  28.9304
# 4  Afghanistan  AFG  1954  29.2258

# %%
df1.tail()
# Out:
#          Entity Code  Year      Age
# 20750  Zimbabwe  ZWE  2017  60.7095
# 20751  Zimbabwe  ZWE  2018  61.4141
# 20752  Zimbabwe  ZWE  2019  61.2925
# 20753  Zimbabwe  ZWE  2020  61.1242
# 20754  Zimbabwe  ZWE  2021  59.2531

# %%
#Eliminando columna
df_dropep = df1.drop(columns = ['Code'])
df_dropep
# Out:
#             Entity  Year      Age
# 0      Afghanistan  1950  27.7275
# 1      Afghanistan  1951  27.9634
# 2      Afghanistan  1952  28.4456
# 3      Afghanistan  1953  28.9304
# 4      Afghanistan  1954  29.2258
# ...            ...   ...      ...
# 20750     Zimbabwe  2017  60.7095
# 20751     Zimbabwe  2018  61.4141
# 20752     Zimbabwe  2019  61.2925
# 20753     Zimbabwe  2020  61.1242
# 20754     Zimbabwe  2021  59.2531
#
# [20755 rows x 3 columns]

# %%
df2 = df_dropep.copy()
df2
# Out:
#             Entity  Year      Age
# 0      Afghanistan  1950  27.7275
# 1      Afghanistan  1951  27.9634
# 2      Afghanistan  1952  28.4456
# 3      Afghanistan  1953  28.9304
# 4      Afghanistan  1954  29.2258
# ...            ...   ...      ...
# 20750     Zimbabwe  2017  60.7095
# 20751     Zimbabwe  2018  61.4141
# 20752     Zimbabwe  2019  61.2925
# 20753     Zimbabwe  2020  61.1242
# 20754     Zimbabwe  2021  59.2531
#
# [20755 rows x 3 columns]

# %%
# Redondeo de los valores en edad a 2 decimales
df2.round(2)
# Out:
#             Entity  Year    Age
# 0      Afghanistan  1950  27.73
# 1      Afghanistan  1951  27.96
# 2      Afghanistan  1952  28.45
# 3      Afghanistan  1953  28.93
# 4      Afghanistan  1954  29.23
# ...            ...   ...    ...
# 20750     Zimbabwe  2017  60.71
# 20751     Zimbabwe  2018  61.41
# 20752     Zimbabwe  2019  61.29
# 20753     Zimbabwe  2020  61.12
# 20754     Zimbabwe  2021  59.25
#
# [20755 rows x 3 columns]

# %%
#Pasando datos demimales a enteros en ['Age']
df2['Age'] = df2['Age'].astype(int)
df2
# Out:
#             Entity  Year  Age
# 0      Afghanistan  1950   27
# 1      Afghanistan  1951   27
# 2      Afghanistan  1952   28
# 3      Afghanistan  1953   28
# 4      Afghanistan  1954   29
# ...            ...   ...  ...
# 20750     Zimbabwe  2017   60
# 20751     Zimbabwe  2018   61
# 20752     Zimbabwe  2019   61
# 20753     Zimbabwe  2020   61
# 20754     Zimbabwe  2021   59
#
# [20755 rows x 3 columns]

# %%
df2['Year'].describe().reset_index()
# Out:
#    index          Year
# 0  count  20755.000000
# 1   mean   1975.730234
# 2    std     38.423230
# 3    min   1543.000000
# 4    25%   1961.000000
# 5    50%   1981.000000
# 6    75%   2001.000000
# 7    max   2021.000000

# %% [markdown]
# #### Funcion para categorizar las edades

# %%
df3 = df2.copy()
df3
# Out:
#             Entity  Year  Age
# 0      Afghanistan  1950   27
# 1      Afghanistan  1951   27
# 2      Afghanistan  1952   28
# 3      Afghanistan  1953   28
# 4      Afghanistan  1954   29
# ...            ...   ...  ...
# 20750     Zimbabwe  2017   60
# 20751     Zimbabwe  2018   61
# 20752     Zimbabwe  2019   61
# 20753     Zimbabwe  2020   61
# 20754     Zimbabwe  2021   59
#
# [20755 rows x 3 columns]

# %%
df3['Year'].describe().reset_index()
# Out:
#    index          Year
# 0  count  20755.000000
# 1   mean   1975.730234
# 2    std     38.423230
# 3    min   1543.000000
# 4    25%   1961.000000
# 5    50%   1981.000000
# 6    75%   2001.000000
# 7    max   2021.000000

# %% [markdown]
# #### Determinar esperanza de vida en:
# * Afganistan

# %%
df_Afghanos = df2[df2['Entity'] == 'Afghanistan']
df_Afghanos
# Out:
#          Entity  Year  Age
# 0   Afghanistan  1950   27
# 1   Afghanistan  1951   27
# 2   Afghanistan  1952   28
# 3   Afghanistan  1953   28
# 4   Afghanistan  1954   29
# ..          ...   ...  ...
# 67  Afghanistan  2017   63
# 68  Afghanistan  2018   63
# 69  Afghanistan  2019   63
# 70  Afghanistan  2020   62
# 71  Afghanistan  2021   61
#
# [72 rows x 3 columns]

# %%
df_Afghanos.groupby('Entity')['Age'].describe()
# Out:
#              count       mean       std   min    25%   50%   75%   max
# Entity
# Afghanistan   72.0  44.861111  11.89189  27.0  34.75  40.0  57.0  63.0

# %%
import matplotlib.pyplot as plt

# Crear la gráfica de líneas
plt.figure(figsize=(10, 6))
plt.plot(df_Afghanos['Year'], df_Afghanos['Age'], marker='o', linestyle='-', color='b')

# Añadir títulos y etiquetas
plt.title('Esperanza de vida en Afghanistan a lo largo del tiempo')
plt.xlabel('Año')
plt.ylabel('Esperanza de vida al nacer (años)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Esperanza de vida en Africa

# %%
df4 = df3.copy()
df4
# Out:
#             Entity  Year  Age
# 0      Afghanistan  1950   27
# 1      Afghanistan  1951   27
# 2      Afghanistan  1952   28
# 3      Afghanistan  1953   28
# 4      Afghanistan  1954   29
# ...            ...   ...  ...
# 20750     Zimbabwe  2017   60
# 20751     Zimbabwe  2018   61
# 20752     Zimbabwe  2019   61
# 20753     Zimbabwe  2020   61
# 20754     Zimbabwe  2021   59
#
# [20755 rows x 3 columns]

# %%
df_Africa = df4[df4['Entity'] == 'Africa']
df_Africa
# Out:
#      Entity  Year  Age
# 72   Africa  1770   26
# 73   Africa  1925   26
# 74   Africa  1950   37
# 75   Africa  1951   37
# 76   Africa  1952   38
# ..      ...   ...  ...
# 141  Africa  2017   61
# 142  Africa  2018   62
# 143  Africa  2019   62
# 144  Africa  2020   62
# 145  Africa  2021   61
#
# [74 rows x 3 columns]

# %%
df_Africa['Year'].describe().reset_index()
# Out:
#    index         Year
# 0  count    74.000000
# 1   mean  1981.770270
# 2    std    33.139203
# 3    min  1770.000000
# 4    25%  1966.250000
# 5    50%  1984.500000
# 6    75%  2002.750000
# 7    max  2021.000000

# %%
df_Africa.groupby('Entity')['Age'].describe()
# Out:
#         count       mean       std   min   25%   50%    75%   max
# Entity
# Africa   74.0  48.864865  7.983415  26.0  43.0  50.0  53.75  62.0

# %%
# Crear la gráfica de líneas
plt.figure(figsize=(10, 6))
plt.plot(df_Africa['Year'], df_Africa['Age'], marker='o', linestyle='-', color='r')

# Añadir títulos y etiquetas
plt.title('Expentacy in Africa along time')
plt.xlabel('Año')
plt.ylabel('Esperanza de vida al nacer (años)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Esperanza de vida en United States

# %%
df5 = df4.copy()
df5
# Out:
#             Entity  Year  Age
# 0      Afghanistan  1950   27
# 1      Afghanistan  1951   27
# 2      Afghanistan  1952   28
# 3      Afghanistan  1953   28
# 4      Afghanistan  1954   29
# ...            ...   ...  ...
# 20750     Zimbabwe  2017   60
# 20751     Zimbabwe  2018   61
# 20752     Zimbabwe  2019   61
# 20753     Zimbabwe  2020   61
# 20754     Zimbabwe  2021   59
#
# [20755 rows x 3 columns]

# %%
df_United_States = df5[df5['Entity'] == 'United States']
df_United_States
# Out:
#               Entity  Year  Age
# 19679  United States  1880   39
# 19680  United States  1890   45
# 19681  United States  1901   49
# 19682  United States  1902   50
# 19683  United States  1903   50
# ...              ...   ...  ...
# 19797  United States  2017   78
# 19798  United States  2018   78
# 19799  United States  2019   79
# 19800  United States  2020   77
# 19801  United States  2021   77
#
# [123 rows x 3 columns]

# %% [markdown]
# #### Escogiendo paises de forma aleatoria

# %%
# Seleccionar una muestra aleatoria de países/regiones
unique_countries = df5['Entity'].unique()
selected_countries = np.random.choice(unique_countries, size=5, replace=False)

selected_countries
# Out:
# array(['Namibia', 'Less developed regions', 'Chad', 'Sierra Leone',
#        'Algeria'], dtype=object)

# %% [markdown]
# #### Esperanza de vida en Europe

# %%
df6 = df5.copy()
df6
# Out:
#             Entity  Year  Age
# 0      Afghanistan  1950   27
# 1      Afghanistan  1951   27
# 2      Afghanistan  1952   28
# 3      Afghanistan  1953   28
# 4      Afghanistan  1954   29
# ...            ...   ...  ...
# 20750     Zimbabwe  2017   60
# 20751     Zimbabwe  2018   61
# 20752     Zimbabwe  2019   61
# 20753     Zimbabwe  2020   61
# 20754     Zimbabwe  2021   59
#
# [20755 rows x 3 columns]

# %%
df_Europe = df5.loc[df5['Entity'] == 'Europe']
df_Europe
# Out:
#       Entity  Year  Age
# 5671  Europe  1770   34
# 5672  Europe  1800   33
# 5673  Europe  1820   35
# 5674  Europe  1850   36
# 5675  Europe  1870   36
# ...      ...   ...  ...
# 5745  Europe  2017   78
# 5746  Europe  2018   78
# 5747  Europe  2019   79
# 5748  Europe  2020   77
# 5749  Europe  2021   77
#
# [79 rows x 3 columns]

# %%
intear = df_Europe['Year'].describe().reset_index().round(1)
intear
# Out:
#    index    Year
# 0  count    79.0
# 1   mean  1973.2
# 2    std    46.9
# 3    min  1770.0
# 4    25%  1962.5
# 5    50%  1982.0
# 6    75%  2001.5
# 7    max  2021.0

# %%
df_Europe.groupby('Entity')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Entity
# Europe   79.0  68.443038  10.484111  33.0  69.0  71.0  73.0  79.0

# %%
#Grafica
plt.figure(figsize = (10,6))
plt.plot(df_Europe['Year'], df_Europe['Age'],marker = 'o', linestyle = '-', color = 'b')
plt.title('Life expentacy in Europe')
plt.xlabel('Year')
plt.ylabel('Expensative life')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Filtrar mas de un pais

# %%
df7 = df6.copy()
df7
# Out:
#             Entity  Year  Age
# 0      Afghanistan  1950   27
# 1      Afghanistan  1951   27
# 2      Afghanistan  1952   28
# 3      Afghanistan  1953   28
# 4      Afghanistan  1954   29
# ...            ...   ...  ...
# 20750     Zimbabwe  2017   60
# 20751     Zimbabwe  2018   61
# 20752     Zimbabwe  2019   61
# 20753     Zimbabwe  2020   61
# 20754     Zimbabwe  2021   59
#
# [20755 rows x 3 columns]

# %%
# Vamos a filtra mas de un dato en la columna Entity
df_Russia = df7[df7['Entity'].isin(['Russia'])]
df_Russia
# Out:
#        Entity  Year  Age
# 15346  Russia  1896   31
# 15347  Russia  1900   30
# 15348  Russia  1920   20
# 15349  Russia  1921   23
# 15350  Russia  1922   24
# ...       ...   ...  ...
# 15439  Russia  2017   73
# 15440  Russia  2018   73
# 15441  Russia  2019   73
# 15442  Russia  2020   71
# 15443  Russia  2021   69
#
# [98 rows x 3 columns]

# %%
df_Asia = df7[df7['Entity'].isin(['Asia'])]
df_Asia
# Out:
#      Entity  Year  Age
# 963    Asia  1770   27
# 964    Asia  1885   27
# 965    Asia  1900   28
# 966    Asia  1913   28
# 967    Asia  1950   42
# ...     ...   ...  ...
# 1034   Asia  2017   73
# 1035   Asia  2018   73
# 1036   Asia  2019   74
# 1037   Asia  2020   73
# 1038   Asia  2021   72
#
# [76 rows x 3 columns]

# %%
df_Russia.groupby('Entity')['Age'].describe()
# Out:
#         count       mean        std   min    25%   50%   75%   max
# Entity
# Russia   98.0  58.928571  14.127001  20.0  52.75  66.0  68.0  73.0

# %%
df_Asia.groupby('Entity')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Entity
# Asia     76.0  58.315789  11.994677  27.0  50.0  61.0  68.0  74.0

# %%
import seaborn as sns
## Configuramos la figura
plt.figure(figsize = (10,6))
# Aplicamos un tema de seaborn
sns.set_theme(style="whitegrid")
#Graficamos los datos de Russia y Asia
plt.plot(df_Russia['Year'], df_Russia['Age'],marker = 'o', linestyle = '-', color = 'b')
plt.plot(df_Asia['Year'], df_Asia['Age'],marker = 'o', linestyle = '-', color = 'r')
# Etiquetamos los ejes y el título con fuentes personalizadas
plt.title('Expentacy life in Asia and Russia', fontsize = 14, fontweight = 'bold')
plt.xlabel('Year', fontsize = 14, fontweight = 'bold')
plt.ylabel('Age',fontsize = 14, fontweight = 'bold')
plt.annotate('Punto importante', xy=(1950, 60), xytext=(1960, 70), arrowprops=dict(facecolor='black', shrink=0.05))

plt.show()
